# %% [markdown]
# <a href="https://colab.research.google.com/github/BinhLe001/FantasyPL/blob/main/FantasyPL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# League ID: 46331

# %% [markdown]
# https://draft.premierleague.com/api/bootstrap-dynamic
#
# https://draft.premierleague.com/api/game
#
# https://draft.premierleague.com/api/bootstrap-static
#
# https://draft.premierleague.com/api/league/{League_ID}/details
#
# https://draft.premierleague.com/api/league/{League_ID}/element-status
#
# https://draft.premierleague.com/api/draft/league/{League_ID}/trades
#
# https://draft.premierleague.com/api/draft/entry/{Team_ID}/transactions
#
# https://draft.premierleague.com/api/pl/event-status
#
# https://draft.premierleague.com/api/event/{GW}/live
#
# https://draft.premierleague.com/api/entry/{Team_ID}/public
#
# https://draft.premierleague.com/api/entry/{Team_ID}/my-team
#
# https://draft.premierleague.com/api/draft/{League_ID}/choices
#
# https://draft.premierleague.com/api/watchlist/{Team_ID}
#
# https://draft.premierleague.com/api/entry/{Team_ID}/event/{GW}

# %%
import json
import requests

fpl_league_details = json.loads(requests.get('https://draft.premierleague.com/api/league/46331/details').text)
fpl_league_details
# Out:
# {'league': {'admin_entry': 172408,
#   'closed': True,
#   'draft_dt': '2023-08-07T01:00:00Z',
#   'draft_pick_time_limit': 90,
#   'draft_status': 'post',
#   'draft_tz_show': 'America/New_York',
#   'id': 46331,
#   'ko_rounds': 0,
#   'make_code_public': False,
#   'max_entries': 10,
#   'min_entries': 2,
#   'name': 'The Finer Things',
#   'scoring': 'h',
#   'start_event': 1,
#   'stop_event': 38,
#   'trades': 'y',
#   'transaction_mode': 'waivers',
#   'variety': 'x'},
#  'league_entries': [{'entry_id': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 173108,
#    'joined_time': '2023-07-31T01:55:26.641939Z',
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'short_name': 'NL',
#    'waiver_pick': 10},
#   {'entry_id': 172479,
#    'entry_name': 'Weebs United',
#    'id': 173181,
#    'joined_time': '2023-07-31T02:09:09.620338Z',
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'short_name': 'BL',
#    'waiver_pick': 5},
#   {'entry_id': 178032,
#    'entry_name': 'Relegation',
#    'id': 178756,
#    'joined_time': '2023-07-31T15:00:37.053747Z',
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'short_name': 'NW',
#    'waiver_pick': 7},
#   {'entry_id': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 179251,
#    'joined_time': '2023-07-31T15:34:45.928997Z',
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'short_name': 'tk',
#    'waiver_pick': 2},
#   {'entry_id': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 219906,
#    'joined_time': '2023-08-03T03:31:30.888155Z',
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'short_name': 'AL',
#    'waiver_pick': 8},
#   {'entry_id': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 247072,
#    'joined_time': '2023-08-04T14:35:57.212127Z',
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'short_name': 'CV',
#    'waiver_pick': 3},
#   {'entry_id': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 274589,
#    'joined_time': '2023-08-05T19:11:57.195303Z',
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'short_name': 'EN',
#    'waiver_pick': 9},
#   {'entry_id': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 276210,
#    'joined_time': '2023-08-05T20:37:28.774521Z',
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'short_name': 'VL',
#    'waiver_pick': 4},
#   {'entry_id': 275105,
#    'entry_name': 'CRG FC',
#    'id': 276578,
#    'joined_time': '2023-08-05T20:57:52.649782Z',
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'short_name': 'CF',
#    'waiver_pick': 6},
#   {'entry_id': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 293899,
#    'joined_time': '2023-08-06T15:51:59.569087Z',
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'short_name': 'SS',
#    'waiver_pick': 1}],
#  'matches': [{'event': 1,
#    'finished': True,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 43,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 62,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 1,
#    'finished': True,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 56,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 42,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 1,
#    'finished': True,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 20,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 38,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 1,
#    'finished': True,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 35,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 53,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 1,
#    'finished': True,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 26,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 37,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 2,
#    'finished': True,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 51,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 42,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 2,
#    'finished': True,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 42,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 60,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 2,
#    'finished': True,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 23,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 26,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 2,
#    'finished': True,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 62,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 35,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 2,
#    'finished': True,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 29,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 30,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 3,
#    'finished': True,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 45,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 24,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 3,
#    'finished': True,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 61,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 32,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 3,
#    'finished': True,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 37,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 46,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 3,
#    'finished': True,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 44,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 72,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 3,
#    'finished': True,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 41,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 34,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 4,
#    'finished': True,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 42,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 32,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 4,
#    'finished': True,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 49,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 73,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 4,
#    'finished': True,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 42,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 23,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 4,
#    'finished': True,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 42,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 30,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 4,
#    'finished': True,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 43,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 39,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 5,
#    'finished': True,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 44,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 46,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 5,
#    'finished': True,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 38,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 40,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 5,
#    'finished': True,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 23,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 45,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 5,
#    'finished': True,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 43,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 27,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 5,
#    'finished': True,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 54,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 26,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 6,
#    'finished': True,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 54,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 41,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 6,
#    'finished': True,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 38,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 53,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 6,
#    'finished': True,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 44,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 37,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 6,
#    'finished': True,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 55,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 43,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 6,
#    'finished': True,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 38,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 41,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 7,
#    'finished': True,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 30,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 41,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 7,
#    'finished': True,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 42,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 55,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 7,
#    'finished': True,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 59,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 47,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 7,
#    'finished': True,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 29,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 73,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 7,
#    'finished': True,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 46,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 37,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 8,
#    'finished': True,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 25,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 53,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 8,
#    'finished': True,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 42,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 38,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 8,
#    'finished': True,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 37,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 19,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 8,
#    'finished': True,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 22,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 53,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 8,
#    'finished': True,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 49,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 37,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 9,
#    'finished': True,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 38,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 44,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 9,
#    'finished': True,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 45,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 24,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 9,
#    'finished': True,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 39,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 62,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 9,
#    'finished': True,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 31,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 49,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 9,
#    'finished': True,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 33,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 60,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 10,
#    'finished': True,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 54,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 63,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 10,
#    'finished': True,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 39,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 28,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 10,
#    'finished': True,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 30,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 40,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 10,
#    'finished': True,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 52,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 21,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 10,
#    'finished': True,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 60,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 36,
#    'started': True,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 11,
#    'finished': False,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 11,
#    'finished': False,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 0,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 11,
#    'finished': False,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 11,
#    'finished': False,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 11,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 12,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 12,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 12,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 12,
#    'finished': False,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 12,
#    'finished': False,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 13,
#    'finished': False,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 13,
#    'finished': False,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 13,
#    'finished': False,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 0,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 13,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 13,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 14,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 14,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 14,
#    'finished': False,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 0,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 14,
#    'finished': False,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 0,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 14,
#    'finished': False,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 15,
#    'finished': False,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 15,
#    'finished': False,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 15,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 15,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 15,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 16,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 16,
#    'finished': False,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 16,
#    'finished': False,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 16,
#    'finished': False,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 0,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 16,
#    'finished': False,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 0,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 17,
#    'finished': False,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 17,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 17,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 17,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 17,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 18,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 18,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 18,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 18,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 18,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 19,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 19,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 19,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 19,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 19,
#    'finished': False,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 20,
#    'finished': False,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 20,
#    'finished': False,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 0,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 20,
#    'finished': False,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 20,
#    'finished': False,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 20,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 21,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 21,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 21,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 21,
#    'finished': False,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 21,
#    'finished': False,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 22,
#    'finished': False,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 22,
#    'finished': False,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 22,
#    'finished': False,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 0,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 22,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 22,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 23,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 23,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 23,
#    'finished': False,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 0,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 23,
#    'finished': False,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 0,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 23,
#    'finished': False,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 24,
#    'finished': False,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 24,
#    'finished': False,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 24,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 24,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 24,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 25,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 25,
#    'finished': False,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 25,
#    'finished': False,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 25,
#    'finished': False,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 0,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 25,
#    'finished': False,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 0,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 26,
#    'finished': False,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 26,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 26,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 26,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 26,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 27,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 27,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 27,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 27,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 27,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 28,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 28,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 28,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 28,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 28,
#    'finished': False,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 29,
#    'finished': False,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 29,
#    'finished': False,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 0,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 29,
#    'finished': False,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 29,
#    'finished': False,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 29,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 30,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 30,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 30,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 30,
#    'finished': False,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 30,
#    'finished': False,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 31,
#    'finished': False,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 31,
#    'finished': False,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 31,
#    'finished': False,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 0,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 31,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 31,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 32,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 32,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 32,
#    'finished': False,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 0,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 32,
#    'finished': False,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 0,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 32,
#    'finished': False,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 33,
#    'finished': False,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 33,
#    'finished': False,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 33,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 33,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 33,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 34,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 34,
#    'finished': False,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 34,
#    'finished': False,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 34,
#    'finished': False,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 0,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 34,
#    'finished': False,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 0,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 35,
#    'finished': False,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 35,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 35,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 35,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 35,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 36,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 36,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 36,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 36,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 36,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 37,
#    'finished': False,
#    'league_entry_1': 274589,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173108,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 37,
#    'finished': False,
#    'league_entry_1': 276210,
#    'league_entry_1_points': 0,
#    'league_entry_2': 247072,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 37,
#    'finished': False,
#    'league_entry_1': 276578,
#    'league_entry_1_points': 0,
#    'league_entry_2': 219906,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 37,
#    'finished': False,
#    'league_entry_1': 293899,
#    'league_entry_1_points': 0,
#    'league_entry_2': 179251,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 37,
#    'finished': False,
#    'league_entry_1': 173181,
#    'league_entry_1_points': 0,
#    'league_entry_2': 178756,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 38,
#    'finished': False,
#    'league_entry_1': 173108,
#    'league_entry_1_points': 0,
#    'league_entry_2': 173181,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 38,
#    'finished': False,
#    'league_entry_1': 178756,
#    'league_entry_1_points': 0,
#    'league_entry_2': 293899,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 38,
#    'finished': False,
#    'league_entry_1': 179251,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276578,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 38,
#    'finished': False,
#    'league_entry_1': 219906,
#    'league_entry_1_points': 0,
#    'league_entry_2': 276210,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None},
#   {'event': 38,
#    'finished': False,
#    'league_entry_1': 247072,
#    'league_entry_1_points': 0,
#    'league_entry_2': 274589,
#    'league_entry_2_points': 0,
#    'started': False,
#    'winning_league_entry': None,
#    'winning_method': None}],
#  'standings': [{'last_rank': 2,
#    'league_entry': 173108,
#    'matches_drawn': 0,
#    'matches_lost': 2,
#    'matches_played': 38,
#    'matches_won': 8,
#    'points_against': 422,
#    'points_for': 452,
#    'rank': 1,
#    'rank_sort': 1,
#    'total': 24},
#   {'last_rank': 1,
#    'league_entry': 274589,
#    'matches_drawn': 0,
#    'matches_lost': 3,
#    'matches_played': 38,
#    'matches_won': 7,
#    'points_against': 392,
#    'points_for': 457,
#    'rank': 2,
#    'rank_sort': 2,
#    'total': 21},
#   {'last_rank': 3,
#    'league_entry': 219906,
#    'matches_drawn': 0,
#    'matches_lost': 3,
#    'matches_played': 38,
#    'matches_won': 7,
#    'points_against': 366,
#    'points_for': 441,
#    'rank': 3,
#    'rank_sort': 3,
#    'total': 21},
#   {'last_rank': 4,
#    'league_entry': 178756,
#    'matches_drawn': 0,
#    'matches_lost': 4,
#    'matches_played': 38,
#    'matches_won': 6,
#    'points_against': 402,
#    'points_for': 411,
#    'rank': 4,
#    'rank_sort': 4,
#    'total': 18},
#   {'last_rank': 5,
#    'league_entry': 276578,
#    'matches_drawn': 0,
#    'matches_lost': 5,
#    'matches_played': 38,
#    'matches_won': 5,
#    'points_against': 387,
#    'points_for': 387,
#    'rank': 5,
#    'rank_sort': 5,
#    'total': 15},
#   {'last_rank': 7,
#    'league_entry': 173181,
#    'matches_drawn': 0,
#    'matches_lost': 6,
#    'matches_played': 38,
#    'matches_won': 4,
#    'points_against': 444,
#    'points_for': 460,
#    'rank': 6,
#    'rank_sort': 6,
#    'total': 12},
#   {'last_rank': 9,
#    'league_entry': 276210,
#    'matches_drawn': 0,
#    'matches_lost': 6,
#    'matches_played': 38,
#    'matches_won': 4,
#    'points_against': 452,
#    'points_for': 400,
#    'rank': 7,
#    'rank_sort': 7,
#    'total': 12},
#   {'last_rank': 6,
#    'league_entry': 247072,
#    'matches_drawn': 0,
#    'matches_lost': 6,
#    'matches_played': 38,
#    'matches_won': 4,
#    'points_against': 400,
#    'points_for': 375,
#    'rank': 8,
#    'rank_sort': 8,
#    'total': 12},
#   {'last_rank': 8,
#    'league_entry': 179251,
#    'matches_drawn': 0,
#    'matches_lost': 7,
#    'matches_played': 38,
#    'matches_won': 3,
#    'points_against': 461,
#    'points_for': 404,
#    'rank': 9,
#    'rank_sort': 9,
#    'total': 9},
#   {'last_rank': 10,
#    'league_entry': 293899,
#    'matches_drawn': 0,
#    'matches_lost': 8,
#    'matches_played': 38,
#    'matches_won': 2,
#    'points_against': 449,
#    'points_for': 388,
#    'rank': 10,
#    'rank_sort': 10,
#    'total': 6}]}

# %%
fpl_league_element_status = json.loads(requests.get('https://draft.premierleague.com/api/league/46331/element-status').text)
fpl_league_element_status
# Out:
# {'element_status': [{'element': 576,
#    'in_accepted_trade': False,
#    'owner': None,
#    'status': 'a'},
#   {'element': 142, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 347, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 586, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 448, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 384, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 80, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 533, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 502, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 138, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 163, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 498, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 474, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 579, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 227, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 189, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 177, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 507, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 481, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 591, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 435, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 121, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 322, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 241, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 154, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 463, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 109, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 84, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 188, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 451, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 530, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 242, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 441, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 299, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 425, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 222, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 2, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 408, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 247, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 551, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 170, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 289, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 376, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 310, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 207, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 409, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 268, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 335, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 500, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 546, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 488, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 379, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 254, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 68, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 411, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 281, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 473, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 317, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 600, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 414, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 578, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 273, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 30, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 38, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 535, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 9, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 240, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 598, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 361, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 570, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 446, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 410, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 439, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 340, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 356, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 496, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 320, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 270, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 37, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 381, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 558, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 479, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 359, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 178, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 580, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 581, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 32, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 257, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 582, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 333, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 229, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 480, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 577, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 248, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 140, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 274, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 422, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 532, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 286, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 187, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 59, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 153, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 263, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 64, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 417, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 53, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 323, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 560, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 465, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 423, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 258, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 495, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 18, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 445, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 296, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 190, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 183, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 244, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 277, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 346, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 192, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 56, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 45, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 218, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 110, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 73, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 76, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 278, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 499, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 181, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 74, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 564, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 116, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 357, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 390, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 51, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 527, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 565, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 40, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 231, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 370, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 413, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 256, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 3, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 282, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 288, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 280, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 484, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 364, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 66, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 284, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 7, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 318, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 81, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 79, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 65, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 604, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 251, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 367, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 334, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 316, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 41, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 269, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 58, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 285, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 15, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 489, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 329, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 128, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 455, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 449, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 63, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 428, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 485, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 283, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 233, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 426, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 298, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 165, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 253, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 385, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 161, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 525, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 195, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 444, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 512, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 239, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 327, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 95, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 521, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 213, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 453, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 421, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 543, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 400, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 194, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 416, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 554, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 99, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 159, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 209, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 514, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 52, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 462, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 158, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 90, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 176, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 24, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 319, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 103, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 255, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 420, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 477, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 35, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 16, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 392, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 541, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 375, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 306, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 252, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 330, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 457, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 508, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 518, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 185, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 432, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 572, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 568, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 575, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 301, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 503, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 537, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 27, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 466, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 86, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 603, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 492, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 105, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 155, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 214, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 461, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 470, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 300, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 475, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 338, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 406, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 315, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 469, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 460, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 228, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 515, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 205, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 397, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 141, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 22, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 276, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 61, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 102, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 563, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 510, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 491, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 401, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 467, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 403, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 34, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 571, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 173, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 464, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 534, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 264, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 271, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 175, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 601, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 351, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 531, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 174, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 39, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 452, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 83, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 391, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 529, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 536, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 266, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 587, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 72, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 389, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 339, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 606, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 25, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 75, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 539, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 260, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 476, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 180, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 47, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 114, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 493, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 93, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 328, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 88, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 443, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 112, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 505, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 1, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 553, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 337, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 55, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 139, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 517, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 172, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 250, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 374, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 431, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 127, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 471, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 123, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 91, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 70, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 583, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 555, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 147, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 497, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 160, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 336, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 191, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 454, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 304, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 458, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 144, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 332, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 133, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 262, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 279, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 67, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 321, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 393, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 456, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 440, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 550, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 57, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 208, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 107, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 162, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 324, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 87, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 238, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 111, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 561, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 562, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 547, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 92, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 429, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 166, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 360, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 96, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 272, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 592, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 259, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 100, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 494, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 366, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 459, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 23, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 82, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 21, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 438, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 4, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 223, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 98, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 193, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 10, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 486, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 404, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 146, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 556, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 182, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 136, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 487, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 236, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 62, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 71, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 201, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 312, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 295, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 585, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 199, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 559, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 545, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 378, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 261, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 552, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 149, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 224, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 237, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 325, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 179, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 434, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 348, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 69, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 566, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 383, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 219, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 150, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 215, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 399, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 104, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 130, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 44, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 602, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 574, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 478, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 358, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 345, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 89, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 196, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 167, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 11, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 245, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 94, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 54, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 513, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 363, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 171, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 137, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 126, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 605, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 243, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 538, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 204, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 157, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 394, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 46, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 331, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 548, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 382, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 371, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 169, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 97, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 588, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 120, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 124, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 573, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 549, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 184, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 235, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 442, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 115, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 380, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 388, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 589, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 200, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 483, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 594, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 164, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 186, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 78, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 292, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 125, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 472, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 490, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 595, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 418, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 156, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 118, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 607, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 608, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 609, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 610, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 612, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 613, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 614, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 617, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 618, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 619, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 620, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 621, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 622, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 623, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 624, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 625, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 626, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 627, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 628, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 629, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 630, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 631, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 632, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 633, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 634, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 635, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 636, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 637, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 639, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 640, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 641, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 642, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 643, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 644, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 645, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 646, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 647, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 648, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 649, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 650, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 651, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 652, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 653, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 654, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 655, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 656, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 657, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 658, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 659, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 661, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 662, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 664, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 665, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 666, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 667, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 668, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 669, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 670, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 671, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 672, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 673, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 674, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 675, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 676, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 678, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 679, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 680, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 681, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 682, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 683, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 684, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 685, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 686, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 687, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 688, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 689, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 690, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 691, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 692, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 693, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 694, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 695, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 696, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 697, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 698, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 700, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 701, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 702, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 703, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 704, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 705, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 706, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 707, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 708, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 709, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 710, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 711, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 712, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 713, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 714, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 715, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 716, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 717, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 718, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 719, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 720, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 721, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 722, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 723, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 724, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 725, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 726, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 727, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 728, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 729, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 730, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 731, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 265, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 148, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 217, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 523, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 369, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 134, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 468, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 305, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 349, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 77, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 433, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 430, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 407, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 221, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 275, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 436, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 482, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 129, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 524, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 516, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 395, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 387, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 313, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 368, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 424, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 49, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 419, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 42, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 230, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 544, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 216, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 398, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 151, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 354, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 26, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 291, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 101, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 308, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 427, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 352, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 249, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 307, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 50, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 342, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 373, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 117, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 569, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 113, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 85, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 267, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 326, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 528, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 344, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 290, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 350, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 504, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 314, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 220, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 396, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 246, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 526, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 60, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 402, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 198, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 14, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 520, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 386, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 557, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 294, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 29, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 225, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 36, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 48, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 597, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 131, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 540, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 302, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 13, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 8, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 31, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 106, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 353, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 437, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 522, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 341, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 509, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 212, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 311, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 145, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 542, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 377, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 119, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 415, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 6, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 405, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 365, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 511, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 447, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 355, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 19, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 28, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 17, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 206, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 5, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 43, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 232, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 226, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 202, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 412, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 450, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 297, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 599, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 234, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 303, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 362, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 584, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 287, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 567, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 309, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 590, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 596, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 33, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 168, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 506, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 12, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 501, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 108, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 293, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 143, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 197, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 343, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 20, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 210, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 372, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 135, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 203, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 519, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 132, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 152, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 593, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 211, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 122, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 611, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 615, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 616, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 638, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 660, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 663, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 677, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 699,
#    'in_accepted_trade': False,
#    'owner': 274742,
#    'status': 'o'}]}

# %%
fpl_league_trades = json.loads(requests.get('https://draft.premierleague.com/api/draft/league/46331/trades').text)
fpl_league_trades
# Out:
# {'trades': [{'event': 1,
#    'id': 55173,
#    'offered_entry': 172408,
#    'offer_time': '2023-08-08T12:09:19.124564Z',
#    'received_entry': 178525,
#    'response_time': '2023-08-08T12:12:45.195372Z',
#    'state': 'p',
#    'tradeitem_set': [{'element_in': 591, 'element_out': 540}]},
#   {'event': 2,
#    'id': 113676,
#    'offered_entry': 218922,
#    'offer_time': '2023-08-15T04:52:14.818098Z',
#    'received_entry': 292200,
#    'response_time': '2023-08-15T13:17:29.777780Z',
#    'state': 'p',
#    'tradeitem_set': [{'element_in': 523, 'element_out': 212}]},
#   {'event': 2,
#    'id': 128393,
#    'offered_entry': 172408,
#    'offer_time': '2023-08-15T23:43:49.582524Z',
#    'received_entry': 275105,
#    'response_time': '2023-08-15T23:45:12.510739Z',
#    'state': 'p',
#    'tradeitem_set': [{'element_in': 377, 'element_out': 197},
#     {'element_in': 117, 'element_out': 207}]},
#   {'event': 5,
#    'id': 332373,
#    'offered_entry': 178525,
#    'offer_time': '2023-09-14T16:57:25.208970Z',
#    'received_entry': 178032,
#    'response_time': '2023-09-14T17:00:50.164121Z',
#    'state': 'p',
#    'tradeitem_set': [{'element_in': 611, 'element_out': 206},
#     {'element_in': 82, 'element_out': 168}]},
#   {'event': 6,
#    'id': 335102,
#    'offered_entry': 178525,
#    'offer_time': '2023-09-16T11:39:35.763017Z',
#    'received_entry': 178032,
#    'response_time': '2023-09-16T13:53:08.764119Z',
#    'state': 'p',
#    'tradeitem_set': [{'element_in': 206, 'element_out': 234},
#     {'element_in': 168, 'element_out': 690}]},
#   {'event': 7,
#    'id': 390353,
#    'offered_entry': 178525,
#    'offer_time': '2023-09-25T19:57:41.875121Z',
#    'received_entry': 273160,
#    'response_time': '2023-09-25T19:57:52.812385Z',
#    'state': 'p',
#    'tradeitem_set': [{'element_in': 96, 'element_out': 611},
#     {'element_in': 412, 'element_out': 344}]},
#   {'event': 7,
#    'id': 400480,
#    'offered_entry': 178525,
#    'offer_time': '2023-09-27T13:10:30.466072Z',
#    'received_entry': 172408,
#    'response_time': '2023-09-27T13:27:08.044643Z',
#    'state': 'p',
#    'tradeitem_set': [{'element_in': 377, 'element_out': 42},
#     {'element_in': 143, 'element_out': 396},
#     {'element_in': 677, 'element_out': 412}]},
#   {'event': 7,
#    'id': 405744,
#    'offered_entry': 178032,
#    'offer_time': '2023-09-28T12:19:34.757728Z',
#    'received_entry': 178525,
#    'response_time': '2023-09-28T14:21:35.983473Z',
#    'state': 'p',
#    'tradeitem_set': [{'element_in': 134, 'element_out': 140},
#     {'element_in': 225, 'element_out': 690}]},
#   {'event': 7,
#    'id': 408172,
#    'offered_entry': 274742,
#    'offer_time': '2023-09-29T02:09:52.719505Z',
#    'received_entry': 172408,
#    'response_time': '2023-09-29T02:11:22.766167Z',
#    'state': 'p',
#    'tradeitem_set': [{'element_in': 6, 'element_out': 209}]},
#   {'event': 9,
#    'id': 470818,
#    'offered_entry': 273160,
#    'offer_time': '2023-10-18T23:46:59.338340Z',
#    'received_entry': 292200,
#    'response_time': '2023-10-19T18:35:34.915075Z',
#    'state': 'p',
#    'tradeitem_set': [{'element_in': 307, 'element_out': 611}]}]}

# %%
fpl_league_choices = json.loads(requests.get('https://draft.premierleague.com/api/draft/46331/choices').text)
fpl_league_choices
# Out:
# {'choices': [{'choice_time': '2023-08-07T01:00:22.557411Z',
#    'element': 355,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930071,
#    'index': 1,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 1,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:01:26.859308Z',
#    'element': 308,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930072,
#    'index': 2,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 1,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:01:34.764411Z',
#    'element': 349,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930073,
#    'index': 3,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 1,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:01:52.224038Z',
#    'element': 500,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930074,
#    'index': 4,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 1,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:02:04.174583Z',
#    'element': 396,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930075,
#    'index': 5,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 1,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:02:57.137254Z',
#    'element': 373,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930076,
#    'index': 6,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 1,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:03:18.584892Z',
#    'element': 19,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930077,
#    'index': 7,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 1,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:03:33.275865Z',
#    'element': 60,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930078,
#    'index': 8,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 1,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:04:31.719324Z',
#    'element': 516,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930079,
#    'index': 9,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 1,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:05:59.177137Z',
#    'element': 212,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930080,
#    'index': 10,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 1,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:06:55.974143Z',
#    'element': 14,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930081,
#    'index': 11,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 2,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:07:04.060344Z',
#    'element': 290,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930082,
#    'index': 12,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 2,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:07:16.684817Z',
#    'element': 12,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930083,
#    'index': 13,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 2,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:07:24.671115Z',
#    'element': 297,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930084,
#    'index': 14,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 2,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:08:29.184366Z',
#    'element': 8,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930085,
#    'index': 15,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 2,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:08:32.848163Z',
#    'element': 415,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930086,
#    'index': 16,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 2,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:09:12.794463Z',
#    'element': 353,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930087,
#    'index': 17,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 2,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:09:23.494710Z',
#    'element': 294,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930088,
#    'index': 18,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 2,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:10:50.841493Z',
#    'element': 354,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930089,
#    'index': 19,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 2,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:12:05.557191Z',
#    'element': 433,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930090,
#    'index': 20,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 2,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:13:00.058737Z',
#    'element': 6,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930091,
#    'index': 21,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 3,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:13:09.877236Z',
#    'element': 211,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930092,
#    'index': 22,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 3,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:13:25.178943Z',
#    'element': 307,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930093,
#    'index': 23,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 3,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:13:45.733969Z',
#    'element': 278,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930094,
#    'index': 24,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 3,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:14:30.375713Z',
#    'element': 303,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930095,
#    'index': 25,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 3,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:14:45.619937Z',
#    'element': 504,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930096,
#    'index': 26,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 3,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:15:54.944192Z',
#    'element': 209,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930097,
#    'index': 27,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 3,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:15:59.197062Z',
#    'element': 343,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930098,
#    'index': 28,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 3,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:17:05.431557Z',
#    'element': 399,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930099,
#    'index': 29,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 3,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:18:10.769196Z',
#    'element': 216,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930100,
#    'index': 30,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 3,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:19:39.414556Z',
#    'element': 293,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930101,
#    'index': 31,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 4,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:21:07.479833Z',
#    'element': 85,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930102,
#    'index': 32,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 4,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:21:24.464393Z',
#    'element': 430,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930103,
#    'index': 33,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 4,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:22:49.780316Z',
#    'element': 509,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930104,
#    'index': 34,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 4,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:22:53.525763Z',
#    'element': 398,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930105,
#    'index': 35,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 4,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:22:58.973673Z',
#    'element': 344,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930106,
#    'index': 36,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 4,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:24:15.988897Z',
#    'element': 526,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930107,
#    'index': 37,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 4,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:24:31.312158Z',
#    'element': 372,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930108,
#    'index': 38,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 4,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:25:45.007081Z',
#    'element': 402,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930109,
#    'index': 39,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 4,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:26:49.428978Z',
#    'element': 313,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930110,
#    'index': 40,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 4,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:28:06.287818Z',
#    'element': 143,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930111,
#    'index': 41,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 5,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:29:20.755784Z',
#    'element': 501,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930112,
#    'index': 42,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 5,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:29:33.354818Z',
#    'element': 29,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930113,
#    'index': 43,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 5,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:29:42.692979Z',
#    'element': 140,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930114,
#    'index': 44,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 5,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:29:49.294926Z',
#    'element': 206,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930115,
#    'index': 45,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 5,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:29:55.520511Z',
#    'element': 195,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930116,
#    'index': 46,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 5,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:31:06.673599Z',
#    'element': 132,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930117,
#    'index': 47,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 5,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:31:31.370031Z',
#    'element': 304,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930118,
#    'index': 48,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 5,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:32:46.701562Z',
#    'element': 5,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930119,
#    'index': 49,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 5,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:34:11.690767Z',
#    'element': 352,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930120,
#    'index': 50,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 5,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:35:32.983731Z',
#    'element': 350,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930121,
#    'index': 51,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 6,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:36:34.728594Z',
#    'element': 368,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930122,
#    'index': 52,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 6,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:36:38.606401Z',
#    'element': 31,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930123,
#    'index': 53,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 6,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:37:09.799020Z',
#    'element': 437,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930124,
#    'index': 54,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 6,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:38:27.331932Z',
#    'element': 291,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930125,
#    'index': 55,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 6,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:38:39.329956Z',
#    'element': 424,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930126,
#    'index': 56,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 6,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:39:11.083538Z',
#    'element': 603,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930127,
#    'index': 57,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 6,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:39:15.129188Z',
#    'element': 119,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930128,
#    'index': 58,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 6,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:40:48.192787Z',
#    'element': 117,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930129,
#    'index': 59,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 6,
#    'seconds_to_pick': None,
#    'was_auto': True},
#   {'choice_time': '2023-08-07T01:42:02.072486Z',
#    'element': 20,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930130,
#    'index': 60,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 6,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:43:10.967684Z',
#    'element': 17,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930131,
#    'index': 61,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 7,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:43:17.243932Z',
#    'element': 585,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930132,
#    'index': 62,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 7,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:43:21.546539Z',
#    'element': 131,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930133,
#    'index': 63,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 7,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:44:22.391047Z',
#    'element': 390,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930134,
#    'index': 64,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 7,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:44:27.545754Z',
#    'element': 134,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930135,
#    'index': 65,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 7,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:45:46.363020Z',
#    'element': 226,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930136,
#    'index': 66,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 7,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:45:57.696081Z',
#    'element': 599,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930137,
#    'index': 67,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 7,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:46:14.594704Z',
#    'element': 49,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930138,
#    'index': 68,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 7,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:46:22.529555Z',
#    'element': 108,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930139,
#    'index': 69,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 7,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:47:24.292477Z',
#    'element': 447,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930140,
#    'index': 70,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 7,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:48:50.006976Z',
#    'element': 217,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930141,
#    'index': 71,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 8,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:49:44.715834Z',
#    'element': 309,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930142,
#    'index': 72,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 8,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:49:48.270067Z',
#    'element': 267,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930143,
#    'index': 73,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 8,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:50:01.419399Z',
#    'element': 210,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930144,
#    'index': 74,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 8,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:50:11.367336Z',
#    'element': 135,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930145,
#    'index': 75,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 8,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:50:52.629775Z',
#    'element': 405,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930146,
#    'index': 76,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 8,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:51:05.322568Z',
#    'element': 346,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930147,
#    'index': 77,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 8,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:51:11.559089Z',
#    'element': 369,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930148,
#    'index': 78,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 8,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:52:10.553503Z',
#    'element': 506,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930149,
#    'index': 79,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 8,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:53:22.182348Z',
#    'element': 450,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930150,
#    'index': 80,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 8,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:53:48.659248Z',
#    'element': 197,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930151,
#    'index': 81,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 9,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:54:43.577434Z',
#    'element': 397,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930152,
#    'index': 82,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 9,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:55:48.593776Z',
#    'element': 525,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930153,
#    'index': 83,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 9,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:56:26.399951Z',
#    'element': 427,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930154,
#    'index': 84,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 9,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:56:37.117920Z',
#    'element': 109,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930155,
#    'index': 85,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 9,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:57:57.258541Z',
#    'element': 26,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930156,
#    'index': 86,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 9,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:58:38.449919Z',
#    'element': 395,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930157,
#    'index': 87,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 9,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:58:43.256389Z',
#    'element': 391,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930158,
#    'index': 88,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 9,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T01:59:12.957569Z',
#    'element': 246,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930159,
#    'index': 89,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 9,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:00:41.787297Z',
#    'element': 341,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930160,
#    'index': 90,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 9,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:01:33.238092Z',
#    'element': 326,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930161,
#    'index': 91,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 10,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:02:58.121003Z',
#    'element': 35,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930162,
#    'index': 92,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 10,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:03:18.872852Z',
#    'element': 51,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930163,
#    'index': 93,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 10,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:03:38.893843Z',
#    'element': 302,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930164,
#    'index': 94,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 10,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:04:50.950878Z',
#    'element': 485,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930165,
#    'index': 95,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 10,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:04:55.878522Z',
#    'element': 225,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930166,
#    'index': 96,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 10,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:05:48.573023Z',
#    'element': 129,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930167,
#    'index': 97,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 10,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:05:52.533122Z',
#    'element': 154,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930168,
#    'index': 98,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 10,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:06:03.293764Z',
#    'element': 377,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930169,
#    'index': 99,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 10,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:07:22.192173Z',
#    'element': 407,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930170,
#    'index': 100,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 10,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:08:17.665723Z',
#    'element': 365,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930171,
#    'index': 101,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 11,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:09:11.045046Z',
#    'element': 187,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930172,
#    'index': 102,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 11,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:09:15.212107Z',
#    'element': 236,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930173,
#    'index': 103,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 11,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:09:53.435743Z',
#    'element': 495,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930174,
#    'index': 104,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 11,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:10:51.223374Z',
#    'element': 535,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930175,
#    'index': 105,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 11,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:10:58.816316Z',
#    'element': 393,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930176,
#    'index': 106,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 11,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:11:22.371640Z',
#    'element': 597,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930177,
#    'index': 107,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 11,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:11:48.988602Z',
#    'element': 13,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930178,
#    'index': 108,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 11,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:13:16.315638Z',
#    'element': 520,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930179,
#    'index': 109,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 11,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:14:38.238278Z',
#    'element': 34,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930180,
#    'index': 110,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 11,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:16:06.208983Z',
#    'element': 511,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930181,
#    'index': 111,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 12,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:16:14.070879Z',
#    'element': 36,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930182,
#    'index': 112,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 12,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:17:31.906742Z',
#    'element': 416,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930183,
#    'index': 113,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 12,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:18:09.723394Z',
#    'element': 48,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930184,
#    'index': 114,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 12,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:18:29.003043Z',
#    'element': 584,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930185,
#    'index': 115,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 12,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:18:49.938404Z',
#    'element': 342,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930186,
#    'index': 116,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 12,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:19:25.915180Z',
#    'element': 112,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930187,
#    'index': 117,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 12,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:20:03.916811Z',
#    'element': 523,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930188,
#    'index': 118,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 12,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:20:18.708323Z',
#    'element': 558,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930189,
#    'index': 119,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 12,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:21:03.628482Z',
#    'element': 401,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930190,
#    'index': 120,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 12,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:21:52.036721Z',
#    'element': 113,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930191,
#    'index': 121,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 13,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:23:09.237567Z',
#    'element': 42,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930192,
#    'index': 122,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 13,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:23:31.522780Z',
#    'element': 101,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930193,
#    'index': 123,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 13,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:25:04.588121Z',
#    'element': 55,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930194,
#    'index': 124,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 13,
#    'seconds_to_pick': None,
#    'was_auto': True},
#   {'choice_time': '2023-08-07T02:25:15.550804Z',
#    'element': 176,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930195,
#    'index': 125,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 13,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:26:45.380286Z',
#    'element': 379,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930196,
#    'index': 126,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 13,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:26:47.714834Z',
#    'element': 103,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930197,
#    'index': 127,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 13,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:27:57.967155Z',
#    'element': 357,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930198,
#    'index': 128,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 13,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:28:26.136041Z',
#    'element': 482,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930199,
#    'index': 129,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 13,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:29:54.556957Z',
#    'element': 159,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930200,
#    'index': 130,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 13,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:31:19.403351Z',
#    'element': 153,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
#    'id': 2930201,
#    'index': 131,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'An',
#    'player_last_name': 'Le',
#    'round': 14,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:31:25.705282Z',
#    'element': 288,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930202,
#    'index': 132,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 14,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:32:27.613692Z',
#    'element': 275,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930203,
#    'index': 133,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 14,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:32:30.330873Z',
#    'element': 519,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930204,
#    'index': 134,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 14,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:32:33.162039Z',
#    'element': 569,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930205,
#    'index': 135,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 14,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:32:37.189065Z',
#    'element': 148,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930206,
#    'index': 136,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 14,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:32:37.270509Z',
#    'element': 502,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930207,
#    'index': 137,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 14,
#    'seconds_to_pick': None,
#    'was_auto': True},
#   {'choice_time': '2023-08-07T02:34:10.336439Z',
#    'element': 507,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930208,
#    'index': 138,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 14,
#    'seconds_to_pick': None,
#    'was_auto': True},
#   {'choice_time': '2023-08-07T02:35:27.285376Z',
#    'element': 281,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930209,
#    'index': 139,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 14,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:35:35.892127Z',
#    'element': 540,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930210,
#    'index': 140,
#    'league': 46331,
#    'pick': 10,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 14,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:35:39.875001Z',
#    'element': 177,
#    'entry': 172408,
#    'entry_name': 'NamsArmyOfChampions',
#    'id': 2930211,
#    'index': 141,
#    'league': 46331,
#    'pick': 1,
#    'player_first_name': 'Nam',
#    'player_last_name': 'Le',
#    'round': 15,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:35:47.570220Z',
#    'element': 263,
#    'entry': 275105,
#    'entry_name': 'CRG FC',
#    'id': 2930212,
#    'index': 142,
#    'league': 46331,
#    'pick': 2,
#    'player_first_name': 'Christian',
#    'player_last_name': 'Farag',
#    'round': 15,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:36:01.214136Z',
#    'element': 152,
#    'entry': 292200,
#    'entry_name': 'EnzoMatic',
#    'id': 2930213,
#    'index': 143,
#    'league': 46331,
#    'pick': 3,
#    'player_first_name': 'Scott',
#    'player_last_name': 'Solomon',
#    'round': 15,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:36:01.303655Z',
#    'element': 533,
#    'entry': 178032,
#    'entry_name': 'Relegation',
#    'id': 2930214,
#    'index': 144,
#    'league': 46331,
#    'pick': 4,
#    'player_first_name': 'Nick',
#    'player_last_name': 'Wester',
#    'round': 15,
#    'seconds_to_pick': None,
#    'was_auto': True},
#   {'choice_time': '2023-08-07T02:36:23.873832Z',
#    'element': 591,
#    'entry': 178525,
#    'entry_name': 'Stinkcopper FC',
#    'id': 2930215,
#    'index': 145,
#    'league': 46331,
#    'pick': 5,
#    'player_first_name': 'taylor',
#    'player_last_name': 'kimbrel',
#    'round': 15,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:36:55.780492Z',
#    'element': 305,
#    'entry': 245921,
#    'entry_name': 'Chadvera FC',
#    'id': 2930216,
#    'index': 146,
#    'league': 46331,
#    'pick': 6,
#    'player_first_name': 'Chad',
#    'player_last_name': 'Verastek',
#    'round': 15,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:37:07.448400Z',
#    'element': 230,
#    'entry': 274742,
#    'entry_name': 'The Pecan Sandies',
#    'id': 2930217,
#    'index': 147,
#    'league': 46331,
#    'pick': 7,
#    'player_first_name': 'Viet',
#    'player_last_name': 'Le',
#    'round': 15,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:37:35.984620Z',
#    'element': 382,
#    'entry': 273160,
#    'entry_name': 'Winnie Wunderkind',
#    'id': 2930218,
#    'index': 148,
#    'league': 46331,
#    'pick': 8,
#    'player_first_name': 'Eric',
#    'player_last_name': 'Nartker',
#    'round': 15,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:38:36.360431Z',
#    'element': 228,
#    'entry': 172479,
#    'entry_name': 'Weebs United',
#    'id': 2930219,
#    'index': 149,
#    'league': 46331,
#    'pick': 9,
#    'player_first_name': 'Binh',
#    'player_last_name': 'Le',
#    'round': 15,
#    'seconds_to_pick': None,
#    'was_auto': False},
#   {'choice_time': '2023-08-07T02:39:58.063566Z',
#    'element': 77,
#    'entry': 218922,
#    'entry_name': 'I <3 White Rice FC',
# ...
#   {'element': 680, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 681, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 682, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 683, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 684, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 685, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 686, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 687, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 688, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 689, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 690, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 691, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 692, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 693, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 694, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 695, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 696, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 697, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 698, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 700, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 701, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 702, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 703, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 704, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 705, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 706, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 707, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 708, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 709, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 710, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 711, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 712, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 713, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 714, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 715, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 716, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 717, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 718, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 719, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 720, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 721, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 722, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 723, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 724, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 725, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 726, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 727, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 728, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 729, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 730, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 731, 'in_accepted_trade': False, 'owner': None, 'status': 'a'},
#   {'element': 265, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 148, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 217, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 523, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 369, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 134, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 468, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 305, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 349, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 77, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 433, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 430, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 407, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 221, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 275, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 436, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 482, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 129, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 524, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 516, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 395, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 387, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 313, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 368, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 424, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 49, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 419, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 42, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 230, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 544, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 216, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 398, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 151, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 354, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 26, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 291, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 101, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 308, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 427, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 352, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 249, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 307, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 50, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 342, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 373, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 117, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 569, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 113, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 85, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 267, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 326, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 528, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 344, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 290, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 350, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 504, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 314, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 220, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 396, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 246, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 526, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 60, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 402, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 198, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 14, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 520, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 386, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 557, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 294, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 29, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 225, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 36, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 48, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 597, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 131, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 540, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 302, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 13, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 8, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 31, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 106, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 353, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 437, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 522, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 341, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 509, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 212, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 311, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 145, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 542, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 377, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 119, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 415, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 6, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 405, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 365, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 511, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 447, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 355, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 19, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 28, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 17, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 206, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 5, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 43, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 232, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 226, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 202, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 412, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 450, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 297, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 599, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 234, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 303, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 362, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 584, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 287, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 567, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 309, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 590, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 596, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 33, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 168, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 506, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 12, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 501, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 108, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 293, 'in_accepted_trade': False, 'owner': 218922, 'status': 'o'},
#   {'element': 143, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 197, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 343, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 20, 'in_accepted_trade': False, 'owner': 172408, 'status': 'o'},
#   {'element': 210, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 372, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 135, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 203, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 519, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 132, 'in_accepted_trade': False, 'owner': 274742, 'status': 'o'},
#   {'element': 152, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 593, 'in_accepted_trade': False, 'owner': 178032, 'status': 'o'},
#   {'element': 211, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 122, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 611, 'in_accepted_trade': False, 'owner': 292200, 'status': 'o'},
#   {'element': 615, 'in_accepted_trade': False, 'owner': 245921, 'status': 'o'},
#   {'element': 616, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 638, 'in_accepted_trade': False, 'owner': 172479, 'status': 'o'},
#   {'element': 660, 'in_accepted_trade': False, 'owner': 273160, 'status': 'o'},
#   {'element': 663, 'in_accepted_trade': False, 'owner': 275105, 'status': 'o'},
#   {'element': 677, 'in_accepted_trade': False, 'owner': 178525, 'status': 'o'},
#   {'element': 699,
#    'in_accepted_trade': False,
#    'owner': 274742,
#    'status': 'o'}]}
